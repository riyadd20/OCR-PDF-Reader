# %%
# !python -m pip install -U pip wheel setuptools

# Install compatible pikepdf that contains PdfMatrix
# !pip install --upgrade --force-reinstall pikepdf==8.15.1

# Install ocrmypdf
# !pip install --upgrade --force-reinstall ocrmypdf==13.7.0
# Out:
# ...
#   Using cached pikepdf-8.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.5 kB)
# ...
#   Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# ...
#   Using cached deprecated-1.3.1-py2.py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached lxml-6.0.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (3.6 kB)
# ...
#   Using cached packaging-26.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached wrapt-2.1.1-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (7.4 kB)
# Using cached pikepdf-8.15.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.4 MB)
# Using cached lxml-6.0.2-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (5.3 MB)
# Using cached pillow-12.1.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached deprecated-1.3.1-py2.py3-none-any.whl (11 kB)
# ...

# %%
import os, signal
os.kill(os.getpid(), signal.SIGKILL)

# %%
# !apt-get update -qq
# !apt-get install -y -qq poppler-utils ghostscript qpdf tesseract-ocr libtesseract-dev
# !pip install -q pikepdf==8.15.1 ocrmypdf==13.7.0
# Out:
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Selecting previously unselected package libqpdf28:amd64.
# (Reading database ... 118799 files and directories currently installed.)
# Preparing to unpack .../libqpdf28_10.6.3-1ubuntu0.1_amd64.deb ...
# Unpacking libqpdf28:amd64 (10.6.3-1ubuntu0.1) ...
# Selecting previously unselected package qpdf.
# Preparing to unpack .../qpdf_10.6.3-1ubuntu0.1_amd64.deb ...
# Unpacking qpdf (10.6.3-1ubuntu0.1) ...
# Setting up libqpdf28:amd64 (10.6.3-1ubuntu0.1) ...
# Setting up qpdf (10.6.3-1ubuntu0.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.11) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
input_pdf = next(iter(uploaded))
print("Uploaded:", input_pdf)
# Out:
#      <input type="file" id="files-6599382e-bd6e-48aa-8041-92e4bbbd38e3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6599382e-bd6e-48aa-8041-92e4bbbd38e3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pikepdf, ocrmypdf
print("pikepdf:", pikepdf.__version__)
print("Has PdfMatrix:", hasattr(pikepdf, "PdfMatrix"))
print("ocrmypdf:", ocrmypdf.__version__)
# Out:
# pikepdf: 8.15.1
# Has PdfMatrix: True
# ocrmypdf: 13.7.0

# %%
# !ocrmypdf --skip-text --jobs 4 --output-type pdfa -l eng --deskew --rotate-pages \
"{input_pdf}" "{input_pdf.replace('.pdf','_searchable.pdf')}"
# Out:
# Scanning contents: 100% 100/100 [00:00<00:00, 715.27page/s]
# Start processing 4 pages concurrently
#     3 page is facing ⇩, confidence 1.92 - confidence too low to rotate
#     4 page is facing ⇧, confidence 2.67 - no change
#     1 page is facing ⇧, confidence 6.75 - no change
#     2 page is facing ⇧, confidence 6.85 - no change
#     5 page is facing ⇧, confidence 2.95 - no change
#     6 page is facing ⇧, confidence 2.17 - no change
#     7 page is facing ⇧, confidence 1.11 - no change
#     8 page is facing ⇧, confidence 0.51 - no change
#     9 page is facing ⇧, confidence 4.63 - no change
#    10 page is facing ⇧, confidence 1.48 - no change
#    11 page is facing ⇧, confidence 2.73 - no change
#    12 page is facing ⇧, confidence 2.39 - no change
#    13 page is facing ⇧, confidence 3.20 - no change
#    15 page is facing ⇧, confidence 3.03 - no change
#    14 page is facing ⇧, confidence 2.65 - no change
#    16 page is facing ⇧, confidence 2.00 - no change
# ...
